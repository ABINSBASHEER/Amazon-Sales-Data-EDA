# %% [markdown]
# # **EXPLORATORY DATA ANALYSIS WITH PYTHON**

# %% [markdown]
# **1. IMPORTING THE REQIRED LIBRARIES FOR EDA**
#
# Below are the libraries that are used to perform EDA.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# **2. LOADING THE DATA INTO THE DATA FRAME.**
#
# We will load the Sales Dataset into the data frame to perform EDA.

# %%
df=pd.read_excel('/content/drive/MyDrive/Project/SALESDATA.xlsx')

df.head()   # To display the top 5 rows
# Out:
#     CustKey    DateKey  Discount Amount Invoice Date  Invoice Number  \
# 0  10000460 2017-01-01           158.04   2017-01-01          119156
# 1  10000460 2017-01-01           420.90   2017-01-01          119156
# 2  10000460 2017-01-01           663.41   2017-01-01          119156
# 3  10000460 2017-01-01           179.45   2017-01-01          119156
# 4  10000460 2017-01-01          1516.52   2017-01-01          119156
#
#   Item Class Item Number                          Item  Line Number  \
# 0        P01       29071     Nationeel Salted Pretzels         8000
# 1        P01       28401          Ebony Prepared Salad         4000
# 2        P01       29255          Thresher Spicy Mints         9000
# 3        P01       36001  Big Time Frozen Cheese Pizza        12000
# 4        P01       47550     Red Spade Turkey Hot Dogs        13000
#
#    List Price  ...  Sales Amount Sales Amount Based on List Price  \
# 0      181.44  ...        204.84                           362.88
# ...

# %%
df.tail()  #To display last 5 rows
# Out:
#         CustKey    DateKey  Discount Amount Invoice Date  Invoice Number  \
# 65277  10026081 2019-12-31         272.5230   2019-12-31          329571
# 65278  10026081 2019-12-31         548.2520   2019-12-31          329573
# 65279  10026081 2019-12-31          26.2588   2019-12-31          329575
# 65280  10026081 2019-12-31         447.6400   2019-12-31          329574
# 65281  10026606 2019-12-31          15.7200   2019-12-31          329580
#
#       Item Class Item Number                          Item  Line Number  \
# 65277        NaN       35009  Better Fancy Canned Sardines         1000
# 65278        NaN       29277             Monarch Spaghetti         1000
# 65279        NaN       19857                Moms Cole Slaw         1000
# 65280        NaN       35012          Swell Canned Peaches         1000
# 65281        NaN       37559             Walrus Chardonnay         1000
#
#        List Price  ...  Sales Amount Sales Amount Based on List Price  \
# ...

# %%
df.sample(10)
# Out:
#         CustKey    DateKey  Discount Amount Invoice Date  Invoice Number  \
# 49167  10009650 2019-06-21         496.8600   2019-06-21          304555
# 59989  10026334 2019-11-01         526.2500   2019-11-01          316248
# 29106  10022450 2017-12-17        1176.3700   2017-12-17          129394
# 18871  10012715 2017-08-26         333.4600   2017-08-26          111404
# 36418  10002161 2018-03-14         431.1900   2018-03-14          225804
# 25358  10015495 2017-11-05        2982.7500   2017-11-05          117697
# 3504   10020914 2017-02-12        3838.9000   2017-02-12          122586
# 54989  10007591 2019-09-07        3974.4633   2019-09-07          311321
# 5691   10025919 2017-03-12         982.2200   2017-03-12          124993
# 5376   10016549 2017-03-10         396.7500   2017-03-10          124747
#
#       Item Class Item Number                             Item  Line Number  \
# 49167        P01       27550                Imagine Popsicles         7000
# ...

# %%
df['Item'].value_counts()
# Out:
# Better Fancy Canned Sardines    1648
# Ebony Prepared Salad            1471
# Moms Sliced Turkey              1192
# Imagine Popsicles               1191
# Discover Manicotti              1126
#                                 ...
# Fast Salted Pretzels               1
# Big Time Fajita French Fries       1
# Fast Raisins                       1
# High Top Shitake Mushrooms         1
# High Top Mushrooms                 1
# Name: Item, Length: 657, dtype: int64

# %% [markdown]
# **3. BASIC INFORMATION ABOUT DATA**
#
# The df.info() helps to understand the data type and information about data, including the number of records in each column, data having null or not null, Data type, the memory usage of the dataset

# %%
df.info()  #Basic information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65282 entries, 0 to 65281
# Data columns (total 22 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CustKey                           65282 non-null  int64
#  1   DateKey                           65282 non-null  datetime64[ns]
#  2   Discount Amount                   65280 non-null  float64
#  3   Invoice Date                      65282 non-null  datetime64[ns]
#  4   Invoice Number                    65282 non-null  int64
#  5   Item Class                        56993 non-null  object
#  6   Item Number                       65241 non-null  object
#  7   Item                              65282 non-null  object
#  8   Line Number                       65282 non-null  int64
#  9   List Price                        65282 non-null  float64
#  10  Order Number                      65282 non-null  int64
# ...

# %% [markdown]
#  **4. KNOW THE DATATYPES**
#
# Knowing the datatypes which you are exploring is very important and an easy process too. Let’s see how it works.

# %%
df.dtypes
# Out:
# CustKey                                      int64
# DateKey                             datetime64[ns]
# Discount Amount                            float64
# Invoice Date                        datetime64[ns]
# Invoice Number                               int64
# Item Class                                  object
# Item Number                                 object
# Item                                        object
# Line Number                                  int64
# List Price                                 float64
# Order Number                                 int64
# Promised Delivery Date              datetime64[ns]
# Sales Amount                               float64
# Sales Amount Based on List Price           float64
# Sales Cost Amount                          float64
# Sales Margin Amount                        float64
# Sales Price                                float64
# Sales Quantity                               int64
# ...

# %% [markdown]
# **5. STATISTICAL SUMMARY**
#
# The information gives a quick and simple description of the data.Can include Count, Mean, Standard Deviation, median, mode, minimum value, maximum value, range, etc.
#
# Statistics summary gives a high-level idea to identify whether the data has any outliers, data entry error, distribution of data such as the data is normally distributed or left/right skewed

# %%
df.describe()
# Out:
#             CustKey  Discount Amount  Invoice Number    Line Number  \
# count  6.528200e+04     65280.000000    65282.000000   65282.000000
# mean   1.001770e+07      1855.574835   216223.662020   23713.849790
# std    7.176148e+03      9037.140888    94992.281866   32664.024053
# min    1.000045e+07   -255820.800000   100012.000000    1000.000000
# 25%    1.001272e+07       246.037500   117931.000000    3000.000000
# 50%    1.001966e+07       441.760000   222869.500000   12000.000000
# 75%    1.002351e+07       999.760000   314318.750000   32000.000000
# max    1.002758e+07    343532.660000   332842.000000  344000.000000
#
#          List Price   Order Number   Sales Amount  \
# count  65282.000000   65282.000000   65282.000000
# mean     514.693380  180583.064352    2852.038373
# std      449.189182   67593.871116   15164.342107
# min        0.000000  100838.000000     200.010000
# 25%      181.560000  115321.000000     308.387500
# ...

# %% [markdown]
#  **6. DROPPING IRRELEVANT COLUMNS**
#
# Some columns or variables can be dropped if they do not add value to our analysis.

# %%
df=df.drop(columns=['U/M','@dropdown','Unnamed: 21'])
df.head()
# Out:
#     CustKey    DateKey  Discount Amount Invoice Date  Invoice Number  \
# 0  10000460 2017-01-01           158.04   2017-01-01          119156
# 1  10000460 2017-01-01           420.90   2017-01-01          119156
# 2  10000460 2017-01-01           663.41   2017-01-01          119156
# 3  10000460 2017-01-01           179.45   2017-01-01          119156
# 4  10000460 2017-01-01          1516.52   2017-01-01          119156
#
#   Item Class Item Number                          Item  Line Number  \
# 0        P01       29071     Nationeel Salted Pretzels         8000
# 1        P01       28401          Ebony Prepared Salad         4000
# 2        P01       29255          Thresher Spicy Mints         9000
# 3        P01       36001  Big Time Frozen Cheese Pizza        12000
# 4        P01       47550     Red Spade Turkey Hot Dogs        13000
#
#    List Price  Order Number Promised Delivery Date  Sales Amount  \
# 0      181.44        216666             2017-01-01        204.84
# ...

# %% [markdown]
# **7. RENAMING COLUMNS**
#
# The df.rename() function rename the columns in the dataset.

# %%
for i in df:
    j=i.replace(' ','_')
    df.rename(columns={i:j.capitalize(),'CustKey':'Cust_key','DateKey':'Date_key'},inplace=True)
df.head()
# Out:
#    Cust_key   Date_key  Discount_amount Invoice_date  Invoice_number  \
# 0  10000460 2017-01-01           158.04   2017-01-01          119156
# 1  10000460 2017-01-01           420.90   2017-01-01          119156
# 2  10000460 2017-01-01           663.41   2017-01-01          119156
# 3  10000460 2017-01-01           179.45   2017-01-01          119156
# 4  10000460 2017-01-01          1516.52   2017-01-01          119156
#
#   Item_class Item_number                          Item  Line_number  \
# 0        P01       29071     Nationeel Salted Pretzels         8000
# 1        P01       28401          Ebony Prepared Salad         4000
# 2        P01       29255          Thresher Spicy Mints         9000
# 3        P01       36001  Big Time Frozen Cheese Pizza        12000
# 4        P01       47550     Red Spade Turkey Hot Dogs        13000
#
#    List_price  Order_number Promised_delivery_date  Sales_amount  \
# 0      181.44        216666             2017-01-01        204.84
# ...

# %% [markdown]
# **8. DROPPING DUPLICATE ROWS**
#
# You can use the df.duplicate.sum() function to the sum of duplicate value present if any. It will show the number of duplicate values if they are present in the data.The df.shape function shows the total number of rows and columns in the ddataset.

# %%
rows_columns=df.shape
print('rows_columns :',rows_columns)
#To find the shape of data rows and colunms

duplicate_rows=df.duplicated().sum()
print('number of duplicate rows: ',duplicate_rows)
# Out:
# rows_columns : (65282, 19)
# number of duplicate rows:  0

# %% [markdown]
#  **9. FINDING THE NULL VALUES.**
#
# Finding the null values is the most important step in the EDA.

# %%
print('null values:-','\n',df.isnull().sum())
# Out:
# null values:-
#  CustKey                                0
# DateKey                                0
# Discount Amount                        2
# Invoice Date                           0
# Invoice Number                         0
# Item Class                          8289
# Item Number                           41
# Item                                   0
# Line Number                            0
# List Price                             0
# Order Number                           0
# Promised Delivery Date                 0
# Sales Amount                           0
# Sales Amount Based on List Price       0
# Sales Cost Amount                      0
# Sales Margin Amount                    0
# Sales Price                            1
# Sales Quantity                         0
# Sales Rep                              0
# dtype: int64

# %% [markdown]
# **10. FILLING THE NULL VALUES**
#
# Here all the missing values are detected and filling

# %%
for i in df:
  df.fillna(100,inplace=True)
df.isnull().sum()
# Out:
# CustKey                             0
# DateKey                             0
# Discount Amount                     0
# Invoice Date                        0
# Invoice Number                      0
# Item Class                          0
# Item Number                         0
# Item                                0
# Line Number                         0
# List Price                          0
# Order Number                        0
# Promised Delivery Date              0
# Sales Amount                        0
# Sales Amount Based on List Price    0
# Sales Cost Amount                   0
# Sales Margin Amount                 0
# Sales Price                         0
# Sales Quantity                      0
# Sales Rep                           0
# dtype: int64

# %% [markdown]
# **11. COMPARISON OPERATOR**
#
# Comparison operator can compare numbers or strings and perform evaluation.Expression that use comparison operator do not return a number value as do arithmetic expressions.

# %%
df['Item']
# Out:
# 0           Nationeel Salted Pretzels
# 1                Ebony Prepared Salad
# 2                Thresher Spicy Mints
# 3        Big Time Frozen Cheese Pizza
# 4           Red Spade Turkey Hot Dogs
#                      ...
# 65277    Better Fancy Canned Sardines
# 65278               Monarch Spaghetti
# 65279                  Moms Cole Slaw
# 65280            Swell Canned Peaches
# 65281               Walrus Chardonnay
# Name: Item, Length: 65282, dtype: object

# %%
df['Sales_price']
# Out:
# 0        102.420000
# 1        545.540000
# 2        286.613333
# 3        232.580000
# 4        655.193333
#             ...
# 65277     37.588276
# 65278     38.700294
# 65279     26.259583
# 65280     13.685758
# 65281      0.377180
# Name: Sales_price, Length: 65282, dtype: float64

# %%
df[(df['Sales_quantity'])==2]
# Out:
#        Cust_key   Date_key  Discount_amount Invoice_date  Invoice_number  \
# 0      10000460 2017-01-01         158.0400   2017-01-01          119156
# 6      10004302 2017-01-01         495.1500   2017-01-01          119109
# 7      10006862 2017-01-01         232.2500   2017-01-01          119114
# 24     10012422 2017-01-01         546.9600   2017-01-01          119094
# 25     10012422 2017-01-01         465.2600   2017-01-01          119134
# ...         ...        ...              ...          ...             ...
# 65265  10023511 2019-12-31        1029.7000   2019-12-31          329641
# 65268  10023511 2019-12-31        1092.1998   2019-12-31          329619
# 65270  10023511 2019-12-31         196.9900   2019-12-31          329641
# 65272  10023511 2019-12-31         489.0600   2019-12-31          329641
# 65274  10023793 2019-12-31         917.5200   2019-12-31          329584
#
#       Item_class Item_number                               Item  Line_number  \
# ...

# %%
df['Date_key']=pd.to_datetime(df['Date_key'])
df[(df['Date_key']>='2017-01-01')&(df['Date_key']<='2017-12-31')]
# Out:
#        Cust_key   Date_key  Discount_amount Invoice_date  Invoice_number  \
# 0      10000460 2017-01-01         158.0400   2017-01-01          119156
# 1      10000460 2017-01-01         420.9000   2017-01-01          119156
# 2      10000460 2017-01-01         663.4100   2017-01-01          119156
# 3      10000460 2017-01-01         179.4500   2017-01-01          119156
# 4      10000460 2017-01-01        1516.5200   2017-01-01          119156
# ...         ...        ...              ...          ...             ...
# 30570  10025575 2017-12-31         239.1200   2017-12-31          219494
# 30571  10026055 2017-12-31         660.6900   2017-12-31          219356
# 30572  10026299 2017-12-31         392.4300   2017-12-31          219386
# 30573  10026299 2017-12-31         295.5325   2017-12-31          219434
# 30574  10026868 2017-12-31         629.6000   2017-12-31          219489
#
#       Item_class Item_number                          Item  Line_number  \
# ...

# %%
df['Date_key']=pd.to_datetime(df['Date_key'])
df[(df['Date_key']>='2018-01-01')&(df['Date_key']<='2018-12-31')]
# Out:
#        Cust_key   Date_key  Discount_amount Invoice_date  Invoice_number  \
# 30575  10003857 2018-01-01          235.750   2018-01-01          219598
# 30576  10003857 2018-01-01         1858.283   2018-01-01          219598
# 30577  10003857 2018-01-01         3075.140   2018-01-01          219598
# 30578  10003857 2018-01-01          929.820   2018-01-01          219598
# 30579  10003857 2018-01-01          399.360   2018-01-01          219598
# ...         ...        ...              ...          ...             ...
# 37256  10017638 2018-03-21          505.780   2018-03-21          226497
# 37257  10017638 2018-03-21          410.750   2018-03-21          226497
# 37258  10017638 2018-03-21          876.160   2018-03-21          226497
# 37259  10017638 2018-03-21        24226.770   2018-03-21          226498
# 37260  10017638 2018-03-21        24479.260   2018-03-21          226498
#
#       Item_class Item_number                             Item  Line_number  \
# ...

# %%
df['Date_key']=pd.to_datetime(df['Date_key'])
df[(df['Date_key']>='2019-01-01')&(df['Date_key']<='2019-12-31')]
# Out:
#        Cust_key   Date_key  Discount_amount Invoice_date  Invoice_number  \
# 37261  10000471 2019-01-12        1279.6300   2019-01-12          319126
# 37262  10000471 2019-01-12         269.3200   2019-01-12          319126
# 37263  10000471 2019-01-12         162.3300   2019-01-12          319126
# 37264  10001818 2019-01-12         639.8200   2019-01-12          319123
# 37265  10002489 2019-01-12         394.0800   2019-01-12          319133
# ...         ...        ...              ...          ...             ...
# 65277  10026081 2019-12-31         272.5230   2019-12-31          329571
# 65278  10026081 2019-12-31         548.2520   2019-12-31          329573
# 65279  10026081 2019-12-31          26.2588   2019-12-31          329575
# 65280  10026081 2019-12-31         447.6400   2019-12-31          329574
# 65281  10026606 2019-12-31          15.7200   2019-12-31          329580
#
#       Item_class Item_number                              Item  Line_number  \
# ...

# %%
df['Discount_amount'].mean()
# Out:
# 1855.521050516222

# %%
df[(df['Discount_amount']<1500)]
# Out:
#        Cust_key   Date_key  Discount_amount Invoice_date  Invoice_number  \
# 0      10000460 2017-01-01         158.0400   2017-01-01          119156
# 1      10000460 2017-01-01         420.9000   2017-01-01          119156
# 2      10000460 2017-01-01         663.4100   2017-01-01          119156
# 3      10000460 2017-01-01         179.4500   2017-01-01          119156
# 5      10000460 2017-01-01         274.8300   2017-01-01          119156
# ...         ...        ...              ...          ...             ...
# 65277  10026081 2019-12-31         272.5230   2019-12-31          329571
# 65278  10026081 2019-12-31         548.2520   2019-12-31          329573
# 65279  10026081 2019-12-31          26.2588   2019-12-31          329575
# 65280  10026081 2019-12-31         447.6400   2019-12-31          329574
# 65281  10026606 2019-12-31          15.7200   2019-12-31          329580
#
#       Item_class Item_number                          Item  Line_number  \
# ...

# %%
df[(df['Discount_amount']>1500)&(df['Sales_amount']<3000)]
# Out:
#        Cust_key   Date_key  Discount_amount Invoice_date  Invoice_number  \
# 4      10000460 2017-01-01          1516.52   2017-01-01          119156
# 116    10019410 2017-01-02          1802.71   2017-01-02          119219
# 156    10024248 2017-01-02          2455.56   2017-01-02          119316
# 160    10024248 2017-01-02          2188.02   2017-01-02          119316
# 175    10025036 2017-01-02          1820.52   2017-01-02          119278
# ...         ...        ...              ...          ...             ...
# 65211  10019194 2019-12-31          2767.37   2019-12-31          329620
# 65216  10019194 2019-12-31          2756.84   2019-12-31          329620
# 65246  10022450 2019-12-31          1631.87   2019-12-31          329615
# 65271  10023511 2019-12-31          2318.15   2019-12-31          329619
# 65275  10023793 2019-12-31          2662.45   2019-12-31          329584
#
#       Item_class Item_number                             Item  Line_number  \
# ...

# %%
df[(df['Discount_amount']>2000)&(df['Discount_amount']<5000)]
# Out:
#        Cust_key   Date_key  Discount_amount Invoice_date  Invoice_number  \
# 38     10019942 2017-01-01          2833.40   2017-01-01          119167
# 42     10020962 2017-01-01          4984.00   2017-01-01          119096
# 156    10024248 2017-01-02          2455.56   2017-01-02          119316
# 160    10024248 2017-01-02          2188.02   2017-01-02          119316
# 176    10025791 2017-01-02          3183.18   2017-01-02          119325
# ...         ...        ...              ...          ...             ...
# 65216  10019194 2019-12-31          2756.84   2019-12-31          329620
# 65230  10019194 2019-12-31          3999.03   2019-12-31          329620
# 65267  10023511 2019-12-31          2717.55   2019-12-31          329641
# 65271  10023511 2019-12-31          2318.15   2019-12-31          329619
# 65275  10023793 2019-12-31          2662.45   2019-12-31          329584
#
#       Item_class Item_number                          Item  Line_number  \
# ...

# %%
df['List_price'].mean()
# Out:
# 514.6933804678166

# %%
df[(df['List_price']>2000)&(df['List_price']<5000)]
# Out:
#        Cust_key   Date_key  Discount_amount Invoice_date  Invoice_number  \
# 3374   10015824 2017-02-11          9165.60   2017-02-11          122441
# 11051  10015824 2017-05-20          9165.60   2017-05-20          102781
# 11420  10021160 2017-05-23         12690.67   2017-05-23          103032
# 11421  10021160 2017-05-23         10575.55   2017-05-23          103031
# 12023  10021160 2017-05-30         31726.66   2017-05-30          103612
# 12699  10021160 2017-06-06         38072.00   2017-06-06          104344
# 12966  10021160 2017-06-10         12690.67   2017-06-10          104624
# 17718  10015824 2017-08-11          9165.60   2017-08-11          110058
# 23222  10015824 2017-10-13         11042.80   2017-10-13          115562
# 23283  10015824 2017-10-14         22085.60   2017-10-14          115710
# 23607  10015824 2017-10-16          1380.35   2017-10-16          115968
# 28835  10015824 2017-12-15         11042.80   2017-12-15          129091
# ...

# %%
df['Sales_price'].unique()
# Out:
# array([1.02420000e+02, 5.45540000e+02, 2.86613333e+02, ...,
#        8.47133333e+01, 2.55358333e+00, 4.99200000e-01])

# %% [markdown]
# **12. MEAN,MEDIAN AND STANDARD DEVIATION**
#
# Here we use df.mean, df.median, df.std for finding the mean, median and standatd deviation of our dataset.

# %%
df.mean()   #To find Mean
# Out:
# <ipython-input-30-8a7679dab295>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.mean()   #To find Mean
# <ipython-input-30-8a7679dab295>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()   #To find Mean
# Cust_key                            1.001770e+07
# Discount_amount                     1.855521e+03
# Invoice_number                      2.162237e+05
# Line_number                         2.371385e+04
# List_price                          5.146934e+02
# Order_number                        1.805831e+05
# Sales_amount                        2.852038e+03
# Sales_amount_based_on_list_price    4.707474e+03
# ...

# %%
df.median()  # To find Median
# Out:
# <ipython-input-31-49c84c3d2313>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.median()  # To find Median
# <ipython-input-31-49c84c3d2313>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()  # To find Median
# Cust_key                            1.001966e+07
# Discount_amount                     4.417600e+02
# Invoice_number                      2.228695e+05
# Line_number                         1.200000e+04
# List_price                          3.251900e+02
# Order_number                        2.037020e+05
# Sales_amount                        5.539400e+02
# Sales_amount_based_on_list_price    9.981600e+02
# ...

# %%
df['List_price'].cumsum()  # To find cumulative sum
# Out:
# 0        1.814400e+02
# 1        1.147880e+03
# 2        1.655630e+03
# 3        2.067660e+03
# 4        3.228360e+03
#              ...
# 65277    3.360013e+07
# 65278    3.360017e+07
# 65279    3.360020e+07
# 65280    3.360021e+07
# 65281    3.360021e+07
# Name: List_price, Length: 65282, dtype: float64

# %%
df.std()   #To find Standard Deviation
# Out:
# <ipython-input-33-161e227fdfbb>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.std()   #To find Standard Deviation
# Cust_key                                            7176.148147
# Date_key                            365 days 14:34:18.221579268
# Discount_amount                                     9037.007677
# Invoice_date                        365 days 14:34:18.221579268
# Invoice_number                                     94992.281866
# Line_number                                        32664.024053
# List_price                                           449.189182
# Order_number                                       67593.871116
# Promised_delivery_date              378 days 13:05:53.939912180
# ...

# %% [markdown]
# **13. CORRELATION PLOT - EDA**
#
# To find the correlation among the variables, we can make use of the correlation function. This will give you a fair idea of the correlation strength between different variables.

# %%
df.corr()
# Out:
# <ipython-input-34-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                                   Cust_key  Discount_amount  Invoice_number  \
# Cust_key                          1.000000        -0.021773       -0.077041
# Discount_amount                  -0.021773         1.000000        0.010560
# Invoice_number                   -0.077041         0.010560        1.000000
# Line_number                       0.033806        -0.044746        0.003674
# List_price                       -0.007856         0.075189        0.011378
# Order_number                      0.054727        -0.006926       -0.667287
# Sales_amount                      0.019044         0.425851       -0.001199
# Sales_amount_based_on_list_price  0.004445         0.748669        0.003738
# ...

# %% [markdown]
# **14. CORRELATION BETWEEN DISCOUNT AMOUNT AND SALES AMOUNT**

# %%
sns.scatterplot(data=df,x='Discount_amount',y='Sales_amount')
plt.title('correlation between discount amount and sales amount ', fontweight='bold')
plt.xlabel('Discount_amount',fontweight='bold')
plt.ylabel('Sales_amount',fontweight='bold')
plt.show()

# %%
sns.heatmap(data = df.corr(), annot = True,linewidths=1)
plt.title('Correlation ', fontweight = 'bold')
plt.show()
# Out:
# <ipython-input-36-4b82a37e183d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data = df.corr(), annot = True,linewidths=1)

# %% [markdown]
# **15. BAR PLOT**
#
# A bar plot can be used to show the relationship betweeen categorical variables and continous variables.
#
# Here the bar plot shows the first and last 15 data of Discount amount and items in the dataset.

# %%
sns.barplot(x='Discount_amount',y='Item',data=df.head(15))
plt.show()

# %%
sns.barplot(x='Discount_amount',y='Item',data=df.tail(15))
plt.show()

# %% [markdown]
# **16. HISTOGRAM**

# %%
plt.hist(data=df.head(50),x='Item', edgecolor='black')

# Adding labels and title
plt.xlabel('Item')
plt.ylabel('Sales_amount')
plt.title('Basic Histogram')
plt.xticks(rotation=90)

# Display the plot
plt.show()

# %% [markdown]
# **17**. **DETECTING OUTLIERS**
#
# An outlier is a point or set of points that are different from other points. Sometimes they can be very high or very low. It's often a good idea to detect and remove the outliers. Because outliers are one of the primary reasons for resulting in a less accurate model. Hence it's a good idea to remove them. The outlier detection and removing that I am going to perform is called IQR score technique. Often outliers can be seen with visualizations using a box plot.

# %%
sns.boxplot(df['Discount_amount'])
# Out:
# <Axes: ylabel='Discount_amount'>

# %%
Q1 = df['Discount_amount'].quantile(0.45)
Q3 = df['Discount_amount'].quantile(0.90)
IQR = Q3 - Q1
print(IQR)
((df['Discount_amount'] < (Q1 - 1.5 * IQR)) | (df['Discount_amount'] > (Q3 + 1.5 * IQR))).sum()
# Out:
# 837.54
# 0

# %%
sns.boxplot(df['Discount_amount'])
# Out:
# <Axes: ylabel='Discount_amount'>

# %%
sns.boxplot(df['Sales_amount'].head(10))
# Out:
# <Axes: ylabel='Sales_amount'>

# %% [markdown]
# **18. LINE PLOT**

# %%
def plot():
  sns.lineplot(x=df['Discount_amount'],y=df['Sales_amount'],data=df.head())
sns.set_palette('vlag')
plt.subplot(211)
plot()



def plot():
  sns.lineplot(x=df['List_price'],y=df['Sales_price'],data=df.head())
sns.set_palette('Accent')
plt.subplot(212)
plot()

# %%
sns.lineplot(x='Date_key',y='List_price',data=df)
plt.xticks(rotation=90)
# Out:
# (array([17167., 17287., 17410., 17532., 17652., 17775., 17897., 18017.,
#         18140., 18262.]),
#  [Text(17167.0, 0, '2017-01'),
#   Text(17287.0, 0, '2017-05'),
#   Text(17410.0, 0, '2017-09'),
#   Text(17532.0, 0, '2018-01'),
#   Text(17652.0, 0, '2018-05'),
#   Text(17775.0, 0, '2018-09'),
#   Text(17897.0, 0, '2019-01'),
#   Text(18017.0, 0, '2019-05'),
#   Text(18140.0, 0, '2019-09'),
#   Text(18262.0, 0, '2020-01')])

# %% [markdown]
# **19. DIST PLOT**
#
# Distplot is also known as the second Histogram it is a slight improvement version of the Histogram.

# %%
sns.distplot(df['List_price'])
plt.show()
# Out:
# <ipython-input-31-ec180f9b201f>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['List_price'])

# %% [markdown]
# **20. JOINT PLOT**
#
# Jointplot is used to draw a plot of two variables with
# bivariate and univariate graphs. It basically combines
# two different plots. It is plotted using the jointplot()
# method.

# %%
sns.jointplot(x='List_price', y='Sales_price', data=df)
plt.show()

# %% [markdown]
# **21. PIE CHART**
#
# Pie charts are commonly used in EDA to visualize the proportion or percentage of different categories that make up a whole. They are particularly useful when there are only a few categories, and the goal is to show the relative size of each category.

# %%
df['Item'].value_counts().head(10).plot(kind='pie',autopct='%1.1f%%')
plt.title('Top Selling Products')
plt.setp(autotexts, size=8, weight="bold")
plt.show()

# %% [markdown]
# **CONCLUSION**
#
# Exploratory data analysis  (EDA) is a process of examining and summarizing data sets to discover patterns,trends,outliers and relationships.EDA can help you gain insights and generate.
